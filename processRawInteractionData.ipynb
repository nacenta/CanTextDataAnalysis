# %% [markdown]
# # Process Raw Interaction Data Script (Interaction Derived Measures)

# %% [markdown]
# ### Imports + Global Setup

# %%
from __future__ import print_function, division
# %matplotlib inline

import sys 

def add_module_path(module_path):
    if module_path not in sys.path:
        sys.path.append(module_path)

add_module_path("../colour/")
add_module_path("../PyEDF/")

import numpy as np
import pandas as pd
import re
import os
import warnings
import math

from matplotlib import pyplot as plt
import scikits.bootstrap as boot

from operator import itemgetter

# import pyedf
# import conf

pd.options.display.mpl_style = 'default'

plt.rcParams['figure.figsize'] = (16.0, 10.0)
plt.set_cmap('gnuplot2')

# %% [markdown]
# ## Global Constants

# %%
# path = './DataDummy'
#path = r'G:\Miguel\Research\Research-Current\CMOS\Git Experiment Only\Logs (For test analysis)'
#path = r'G:\Miguel\Research\Research-Current\CMOS\pilot data'
path = r'.\rawData'
#participant_ids = [ 'None', 'Johanas' ]
participant_ids =  [ '15FM24',
                     '21MDC20',
                     '3MW2421',
                     '22F',
                     '14JG23',
                     '1MQ2201',
                     '2ML3603',
                     '8FC02',
                     '5MS3205',
                     '9FH04',
                     '1MW2207',
                     '12FRH06',
                     '6MDH09',
                     '13MM08',
                     '12JR11',
                     '10F',
                     '17MRW13',
                     '12F',
                     'MPS15',
                     '2FQ2014',
                     '5MS17',
                     '2FS2116',
                     '18MDM19',
                     '18F']
condition_ids = ['e', 'c', 's', 'n']
#condition_ids = ['e', 'c']
mediaObjectsPerDocument = 20 # this comes from how the documents were set up.
mediaObjectsScotland = 4 # this comes from how the documents were set up.

# %% [markdown]
# ## Utility Functions

# %%
def loadFileOfParticipantConditionLogtype(path,participantID,condition,logTypeEnding):
# Selects and loads a file from a participantID, of a given condition, of a particular type    
    regular_expression = str(participantID)+"__\S+_"+condition+"\S*"+logTypeEnding+".csv"
    filere = re.compile(regular_expression)
    frames = []
    numProcessedFiles = 0;    
    print('Loading file of type: '+logTypeEnding+", condition: "+condition+" , participant: "+participantID)
    for filename in os.listdir(path):      
        filematch = filere.match(filename)
        if filematch:
            filepath = path+'/'+filename
            print(filepath)            
            frame = pd.read_csv(filepath,delimiter=',',engine="python",header=0)
            print("Rows loaded: "+str(len(frame.index)))  
            frames.append(frame)            
            numProcessedFiles += 1;
        #else:
            #print("Tried to match: "+filename)
            #print("With RE: "+regular_expression)
    print(str(numProcessedFiles)+" processed files.")
    if (numProcessedFiles > 2):
        warnings.warn("Warning!!: I'm getting more than two files for the same participant and the same condition. Clash in ID's?")
    elif (numProcessedFiles < 2):
        warnings.warn("Warning!!: I should be finding two files for participant:"+participantID+" and condition:"+condition+" and I'm getting less.")
    return frames

def cleanSpacesInColumns(frame):
    columns = frame.columns
    newColumns = []
    ix = 0
    for columnName in columns:
        newColumns.append(columnName.strip(' \n\t'))
        ix += 1
    frame.columns = newColumns
    return frame

# From: http://stackoverflow.com/questions/6987285/python-find-the-item-with-maximum-occurrences
# Ned Deili
def max_occurrences(seq):
    c = dict()
    for item in seq:
        c[item] = c.get(item, 0) + 1
    return max(c.iteritems(), key=itemgetter(1))

# %% [markdown]
# ## Analysis Functions

# %%
def processRawInteractions(rawInteractionsFrame):
    # first clean up unnecessary columns, and rename the x
    frame = cleanSpacesInColumns(rawInteractionsFrame)
    
    # Prepare the output of this function: it's a dictionary
    values = {}
    valueMeanings = {}
    
    values['userId'] = frame.iloc[0].userId
    valueMeanings['userId'] = 'the identification number of the user'
    values['type'] = frame.iloc[0].type
    valueMeanings['type'] = 'the type of trial, i.e., the condition. One of (e=eyecantext, c=cantext, s=static, n=no-images)'
    values['country'] = frame.iloc[0].country
    valueMeanings['country'] = 'the document the trial was done in. One of (0=Scotland(training), 1=Laos, 2=Vanuatu, 3=Suriname, 4=Equatorial Guinea)'
    values['orderNumber'] = frame.iloc[0].orderNumber
    valueMeanings['orderNumber'] = 'the id of the order in which participants faced the conditions and the documents. Goes from 0 to 23'
    values['experimentNumber'] = frame.iloc[0].experimentNumber
    valueMeanings['experimentNumber'] = 'to be completed'
    values['training'] = frame.iloc[0].training
    valueMeanings['experimentNumber'] = 'whether this data comes from training or not'
    
    # Cleanup: This file does not use cleanup. It counts interaction from beginning to end
    
    # Variables needed for the iteration    
    ixInt = 0 # index to iterate over the file
    prevX = -1 # previous position of X 
    prevY = -1 # previous position of Y
    intLength = 0.0 # counts the interaction length in pixels 
    timeScrolling = 0 # counts the scrolling duration in miliseconds
    scrollingState = 0 # represents the scrolling state 0 = not scrolling, 1 = scrolling
    scrollingStartTime = -1 # temporary variable to calculate the duration of a scroll
    
    previousObject = "none" # stores from one iteration to the next which kind of object
    previousTime = -1 # stores from one iteration to the next the time
    
    totalTime = 0 # total overall cursor time counted
    timeInText = 0 # total overall cursor time in text
    timeInMedia = 0 # total overall cursor time in media objects
    timeInOther = 0 # total overall cursor time in other (generally empty space, or None)
    
    totalClicks = 0 # Number of clicks
    clicksOnText = 0 # Count of clicks on text
    clicksOnMedia = 0 # Count of clicks on media
    clicksOnOther = 0 # Count of clicks on other
    clickState = 0 # the current state of click - 0 not clicked - 1 clicked
        
    while True: # Now we iterate over the whole table to get values
        
        if (not(len(frame)>ixInt+1)): # this is the condition of ending
            break # break when we are done processing the length of the frame

        # Extract all the data that we are going to need
        currentTime = frame.iloc[ixInt].timestamp
        currentObject = frame.iloc[ixInt].contentType
        scrolling = frame.iloc[ixInt].scrolling
        currentClick = frame.iloc[ixInt].mouseClick
        x = frame.iloc[ixInt].x
        y = frame.iloc[ixInt].y
                
        # Dealing with the transitions from scrolling to not scrolling
        if (scrollingState == 0):
            if (scrolling == 0): # boring case
                pass # Do nothing                                
            if (scrolling == 1): # we start a scroll movement
                scrollingState = 1 # switch to scrolling state
                scrollingStartTime = currentTime                
        if (scrollingState == 1):
            if (scrolling == 0): # we are ending a scroll movement
                scrollingState = 0
                timeScrolling += (currentTime - scrollingStartTime)
                scrollingStartTime = 0                
            if (scrolling == 1): # boring case: we keep going
                pass # Do nothing            
        
        # Calculate clicks in different object types (we count at the beginning of the click)
        if (clickState == 0):
            if (currentClick == 1): #starting a click
                totalClicks += 1
                clickState = 1
                if (currentObject =='text'):
                    clicksOnText += 1
                elif (currentObject =='media'):
                    clicksOnMedia += 1
                elif (currentObject =='none'):
                    clicksOnOther += 1
                else:
                    print('!!!! Warning, type of object not recognized.')
            else:
                pass # do nothing (no clicking state and no clicking starting)
        elif (clickState == 1):
            if (currentClick == 1): #same click as before, move on
                pass # do nothing
            elif (currentClick == 0): #click is ending
                clickState = 0
        
        
        # Calculate cursor time in different object types
        # Note: we assume that the cursor was on the previous object until the beginning of 
        #       the current line
        if (previousTime == -1): # starting case
            previousTime = currentTime
            previousObject = currentObject
        else:
            totalTime += currentTime - previousTime
            if (previousObject == 'text'):
                timeInText += currentTime - previousTime
            elif (previousObject == 'media'):
                timeInMedia += currentTime - previousTime
            elif (previousObject == 'none'):
                timeInOther += currentTime - previousTime
            else:
                print('!!!! Warning, type of object not recognized.')
            previousTime = currentTime
            previousObject = currentObject
                    
        # Calculate cursor movements
        if (not((prevX == -1) & (prevY == -1))):
            intLength += math.sqrt(math.pow(x-prevX,2)+math.pow(y-prevY,2)) # add the current 

        prevX = x
        prevY = y
        
        ixInt += 1 # incrementing to keep iterating (it's a while loop)
        
    # Storing value results

    values['M14'] = timeScrolling
    valueMeanings['M14'] = 'time during scrolling motions'
 
    values['M15'] = totalClicks
    valueMeanings['M16'] = 'overall number of clicks'
    
    values['M15t'] = clicksOnText
    valueMeanings['M15t'] = 'number of clicks on text'

    values['M15m'] = clicksOnMedia
    valueMeanings['M15m'] = 'number of clicks on media'

    values['M15o'] = clicksOnOther
    valueMeanings['M15o'] = 'number of clicks on other (no object)'


    values['M16'] = totalTime
    valueMeanings['M16'] = 'time counted for cursor positions'
    
    values['M16t'] = timeInText
    valueMeanings['M16t'] = 'time spent by the cursor in text'

    values['M16m'] = timeInMedia
    valueMeanings['M16m'] = 'time spent by the cursor in media'

    values['M16o'] = timeInOther
    valueMeanings['M16o'] = 'time spent by the cursor in other (no object)'

    values['M16t'] = timeInText
    valueMeanings['M16t'] = 'time spent by the cursor in text'

    
    values['M17'] = intLength
    valueMeanings['M17'] = 'overall length of the cursor movement (with respect to document ie includes scrolling)'

    return [values, valueMeanings]

# %% [markdown]
# ## Main Analysis Below

# %%
# Calculate Interaction Metrics
interactionMeasuresDataRows = []
interactionMeasuresDataMeanings = []
rowCount = 0
for participantID in participant_ids:
    print('**-Participant:'+participantID)
    for conditionID in condition_ids:
        print('----Condition:'+conditionID)
        frames = loadFileOfParticipantConditionLogtype(path,
                                                           participantID,
                                                           conditionID,
                                                           'mouseData')
        len(frames)
        for frame in frames:
            processedDataRows = processRawInteractions(frame)
            # print('len of processed data rows:'+str(len(processedDataRows)))
            interactionMeasuresDataRows.append(processedDataRows[0])
            rowCount += 1
            # print('rowCount:'+str(rowCount))
            if (len(interactionMeasuresDataMeanings) == 0):
                interactionMeasuresDataMeanings = processedDataRows[1]

interactionMeasures = pd.DataFrame(interactionMeasuresDataRows)
interactionMeasures.to_pickle(r'.\processedData\interactionAnalysisResults_pandas.pddf')
interactionMeasures.to_csv(r'.\processedData\interactionAnalysisResults.csv')
#fixationMeasuresDataMeanings.to_csv('.\processedData\fixationAnalysisColumnExplanations.csv')
# Out:
# **-Participant:15FM24
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 15FM24
# .\rawData/15FM24__125_e_0_24__2016_9_16_16_33_8_mouseData.csv
# Rows loaded: 283
# .\rawData/15FM24__126_e_3_24__2016_9_16_16_41_0_mouseData.csv
# Rows loaded: 952
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 15FM24
# .\rawData/15FM24__123_c_0_24__2016_9_16_16_22_3_mouseData.csv
# Rows loaded: 2293
# .\rawData/15FM24__124_c_4_24__2016_9_16_16_30_41_mouseData.csv
# Rows loaded: 2459
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 15FM24
# .\rawData/15FM24__129_s_0_24__2016_9_16_16_52_11_mouseData.csv
# Rows loaded: 439
# .\rawData/15FM24__130_s_1_24__2016_9_16_17_0_40_mouseData.csv
# Rows loaded: 1284
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 15FM24
# .\rawData/15FM24__127_n_0_24__2016_9_16_16_42_57_mouseData.csv
# Rows loaded: 319
# .\rawData/15FM24__128_n_2_24__2016_9_16_16_49_50_mouseData.csv
# Rows loaded: 1654
# 2 processed files.
# **-Participant:21MDC20
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 21MDC20
# .\rawData/21MDC20__161_e_0_20__2016_9_19_15_36_30_mouseData.csv
# Rows loaded: 691
# .\rawData/21MDC20__162_e_2_20__2016_9_19_15_47_6_mouseData.csv
# Rows loaded: 2436
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 21MDC20
# .\rawData/21MDC20__159_c_0_20__2016_9_19_15_24_51_mouseData.csv
# Rows loaded: 1479
# .\rawData/21MDC20__160_c_3_20__2016_9_19_15_34_44_mouseData.csv
# Rows loaded: 1545
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 21MDC20
# .\rawData/21MDC20__155_s_0_20__2016_9_19_14_59_38_mouseData.csv
# Rows loaded: 1123
# .\rawData/21MDC20__156_s_4_20__2016_9_19_15_10_3_mouseData.csv
# Rows loaded: 2000
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 21MDC20
# .\rawData/21MDC20__157_n_0_20__2016_9_19_15_13_5_mouseData.csv
# Rows loaded: 1483
# .\rawData/21MDC20__158_n_1_20__2016_9_19_15_22_31_mouseData.csv
# Rows loaded: 1325
# 2 processed files.
# **-Participant:3MW2421
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 3MW2421
# .\rawData/3MW2421__40_e_0_21__2016_6_20_14_46_13_mouseData.csv
# Rows loaded: 262
# .\rawData/3MW2421__41_e_3_21__2016_6_20_14_52_43_mouseData.csv
# Rows loaded: 894
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 3MW2421
# .\rawData/3MW2421__34_c_0_21__2016_6_20_14_11_6_mouseData.csv
# Rows loaded: 2413
# .\rawData/3MW2421__35_c_4_21__2016_6_20_14_19_24_mouseData.csv
# Rows loaded: 2078
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 3MW2421
# .\rawData/3MW2421__38_s_0_21__2016_6_20_14_32_53_mouseData.csv
# Rows loaded: 521
# .\rawData/3MW2421__39_s_1_21__2016_6_20_14_40_55_mouseData.csv
# Rows loaded: 1059
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 3MW2421
# .\rawData/3MW2421__36_n_0_21__2016_6_20_14_21_54_mouseData.csv
# Rows loaded: 386
# .\rawData/3MW2421__37_n_2_21__2016_6_20_14_29_41_mouseData.csv
# Rows loaded: 657
# 2 processed files.
# **-Participant:22F
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 22F
# .\rawData/22F__198_e_0_22__2016_12_15_16_4_58_mouseData.csv
# Rows loaded: 473
# .\rawData/22F__199_e_3_22__2016_12_15_16_23_8_mouseData.csv
# Rows loaded: 1974
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 22F
# .\rawData/22F__194_c_0_22__2016_12_15_15_15_0_mouseData.csv
# Rows loaded: 2012
# .\rawData/22F__195_c_4_22__2016_12_15_15_32_3_mouseData.csv
# Rows loaded: 4699
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 22F
# .\rawData/22F__200_s_0_22__2016_12_15_16_27_32_mouseData.csv
# Rows loaded: 802
# .\rawData/22F__201_s_1_22__2016_12_15_16_40_11_mouseData.csv
# Rows loaded: 3068
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 22F
# .\rawData/22F__196_n_0_22__2016_12_15_15_41_37_mouseData.csv
# Rows loaded: 682
# .\rawData/22F__197_n_2_22__2016_12_15_15_57_39_mouseData.csv
# Rows loaded: 2392
# 2 processed files.
# **-Participant:14JG23
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 14JG23
# .\rawData/14JG23__115_e_0_23__2016_9_16_14_55_21_mouseData.csv
# Rows loaded: 462
# .\rawData/14JG23__116_e_3_23__2016_9_16_15_4_4_mouseData.csv
# Rows loaded: 953
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 14JG23
# .\rawData/14JG23__121_c_0_23__2016_9_16_15_37_46_mouseData.csv
# Rows loaded: 1530
# .\rawData/14JG23__122_c_4_23__2016_9_16_15_46_28_mouseData.csv
# Rows loaded: 2010
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 14JG23
# .\rawData/14JG23__117_s_0_23__2016_9_16_15_9_4_mouseData.csv
# Rows loaded: 547
# .\rawData/14JG23__118_s_1_23__2016_9_16_15_22_4_mouseData.csv
# Rows loaded: 1535
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 14JG23
# .\rawData/14JG23__119_n_0_23__2016_9_16_15_26_2_mouseData.csv
# Rows loaded: 458
# .\rawData/14JG23__120_n_2_23__2016_9_16_15_34_29_mouseData.csv
# Rows loaded: 687
# 2 processed files.
# **-Participant:1MQ2201
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 1MQ2201
# .\rawData/1MQ2201__0_e_0_1__2016_1_22_15_28_42_mouseData.csv
# Rows loaded: 553
# .\rawData/1MQ2201__1_e_1_1__2016_1_22_15_38_10_mouseData.csv
# Rows loaded: 497
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 1MQ2201
# .\rawData/1MQ2201__2_c_0_1__2016_1_22_15_44_35_mouseData.csv
# Rows loaded: 2492
# .\rawData/1MQ2201__3_c_2_1__2016_1_22_15_54_41_mouseData.csv
# Rows loaded: 6650
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 1MQ2201
# .\rawData/1MQ2201__4_s_3_1__2016_1_22_16_13_24_mouseData.csv
# Rows loaded: 1012
# 1 processed files.
# C:\Users\xz32\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:24: UserWarning: Warning!!: I should be finding two files for participant:1MQ2201 and condition:s and I'm getting less.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 1MQ2201
# .\rawData/1MQ2201__5_n_0_1__2016_1_22_16_17_18_mouseData.csv
# Rows loaded: 323
# .\rawData/1MQ2201__6_n_4_1__2016_1_22_16_28_0_mouseData.csv
# Rows loaded: 568
# 2 processed files.
# **-Participant:2ML3603
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 2ML3603
# .\rawData/2ML3603__7_e_0_3__2016_4_19_16_21_38_mouseData.csv
# Rows loaded: 1509
# .\rawData/2ML3603__8_e_1_3__2016_4_19_16_30_26_mouseData.csv
# Rows loaded: 565
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 2ML3603
# .\rawData/2ML3603__11_c_0_3__2016_4_19_16_48_51_mouseData.csv
# Rows loaded: 1070
# .\rawData/2ML3603__12_c_2_3__2016_4_19_16_56_19_mouseData.csv
# Rows loaded: 1644
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 2ML3603
# .\rawData/2ML3603__10_s_3_3__2016_4_19_16_45_42_mouseData.csv
# Rows loaded: 902
# .\rawData/2ML3603__9_s_0_3__2016_4_19_16_36_6_mouseData.csv
# Rows loaded: 713
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 2ML3603
# .\rawData/2ML3603__13_n_0_3__2016_4_19_16_59_22_mouseData.csv
# Rows loaded: 1423
# .\rawData/2ML3603__14_n_4_3__2016_4_19_17_7_16_mouseData.csv
# Rows loaded: 2468
# 2 processed files.
# **-Participant:8FC02
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 8FC02
# .\rawData/8FC02__68_e_0_2__2016_7_12_13_55_8_mouseData.csv
# Rows loaded: 951
# .\rawData/8FC02__69_e_1_2__2016_7_12_14_8_39_mouseData.csv
# Rows loaded: 911
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 8FC02
# .\rawData/8FC02__70_c_0_2__2016_7_12_14_11_58_mouseData.csv
# Rows loaded: 369
# .\rawData/8FC02__71_c_2_2__2016_7_12_14_23_0_mouseData.csv
# Rows loaded: 2779
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 8FC02
# .\rawData/8FC02__74_s_0_2__2016_7_12_14_37_3_mouseData.csv
# Rows loaded: 357
# .\rawData/8FC02__75_s_3_2__2016_7_12_14_46_3_mouseData.csv
# Rows loaded: 1106
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 8FC02
# .\rawData/8FC02__72_n_0_2__2016_7_12_14_25_47_mouseData.csv
# Rows loaded: 260
# .\rawData/8FC02__73_n_4_2__2016_7_12_14_34_48_mouseData.csv
# Rows loaded: 752
# 2 processed files.
# **-Participant:5MS3205
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 5MS3205
# .\rawData/5MS3205__52_e_0_5__2016_6_23_15_30_26_mouseData.csv
# Rows loaded: 1093
# .\rawData/5MS3205__53_e_1_5__2016_6_23_15_36_53_mouseData.csv
# Rows loaded: 560
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 5MS3205
# .\rawData/5MS3205__56_c_0_5__2016_6_23_15_54_4_mouseData.csv
# Rows loaded: 1689
# .\rawData/5MS3205__57_c_2_5__2016_6_23_16_3_46_mouseData.csv
# Rows loaded: 576
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 5MS3205
# .\rawData/5MS3205__58_s_0_5__2016_6_23_16_5_54_mouseData.csv
# Rows loaded: 323
# .\rawData/5MS3205__59_s_3_5__2016_6_23_16_17_5_mouseData.csv
# Rows loaded: 1440
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 5MS3205
# .\rawData/5MS3205__54_n_0_5__2016_6_23_15_40_16_mouseData.csv
# Rows loaded: 214
# .\rawData/5MS3205__55_n_4_5__2016_6_23_15_49_51_mouseData.csv
# Rows loaded: 314
# 2 processed files.
# **-Participant:9FH04
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 9FH04
# .\rawData/9FH04__76_e_0_4__2016_7_12_15_38_34_mouseData.csv
# Rows loaded: 730
# .\rawData/9FH04__77_e_1_4__2016_7_12_15_46_6_mouseData.csv
# Rows loaded: 3444
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 9FH04
# .\rawData/9FH04__82_c_0_4__2016_7_12_16_7_34_mouseData.csv
# Rows loaded: 2103
# .\rawData/9FH04__83_c_2_4__2016_7_12_16_13_3_mouseData.csv
# Rows loaded: 5480
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 9FH04
# .\rawData/9FH04__78_s_0_4__2016_7_12_15_50_6_mouseData.csv
# Rows loaded: 1998
# .\rawData/9FH04__79_s_3_4__2016_7_12_15_57_44_mouseData.csv
# Rows loaded: 1374
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 9FH04
# .\rawData/9FH04__80_n_0_4__2016_7_12_16_0_58_mouseData.csv
# Rows loaded: 1282
# .\rawData/9FH04__81_n_4_4__2016_7_12_16_5_21_mouseData.csv
# Rows loaded: 1777
# 2 processed files.
# **-Participant:1MW2207
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 1MW2207
# .\rawData/1MW2207__24_e_0_7__2016_6_15_15_33_19_mouseData.csv
# Rows loaded: 443
# .\rawData/1MW2207__25_e_4_7__2016_6_15_15_43_1_mouseData.csv
# Rows loaded: 630
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 1MW2207
# .\rawData/1MW2207__20_c_0_7__2016_6_15_15_10_6_mouseData.csv
# Rows loaded: 1776
# .\rawData/1MW2207__21_c_1_7__2016_6_15_15_20_31_mouseData.csv
# Rows loaded: 2972
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 1MW2207
# .\rawData/1MW2207__18_s_0_7__2016_6_15_14_55_38_mouseData.csv
# Rows loaded: 747
# .\rawData/1MW2207__19_s_2_7__2016_6_15_15_5_18_mouseData.csv
# Rows loaded: 690
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 1MW2207
# .\rawData/1MW2207__22_n_0_7__2016_6_15_15_22_47_mouseData.csv
# Rows loaded: 480
# .\rawData/1MW2207__23_n_3_7__2016_6_15_15_30_40_mouseData.csv
# Rows loaded: 1267
# 2 processed files.
# **-Participant:12FRH06
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 12FRH06
# .\rawData/12FRH06__92_e_0_6__2016_9_15_15_53_49_mouseData.csv
# Rows loaded: 567
# .\rawData/12FRH06__93_e_1_6__2016_9_15_16_1_16_mouseData.csv
# Rows loaded: 407
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 12FRH06
# .\rawData/12FRH06__98_c_0_6__2016_9_15_16_28_37_mouseData.csv
# Rows loaded: 3537
# .\rawData/12FRH06__99_c_2_6__2016_9_15_16_37_26_mouseData.csv
# Rows loaded: 2407
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 12FRH06
# .\rawData/12FRH06__96_s_0_6__2016_9_15_16_16_30_mouseData.csv
# Rows loaded: 567
# .\rawData/12FRH06__97_s_3_6__2016_9_15_16_25_56_mouseData.csv
# Rows loaded: 802
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 12FRH06
# .\rawData/12FRH06__94_n_0_6__2016_9_15_16_3_41_mouseData.csv
# Rows loaded: 469
# .\rawData/12FRH06__95_n_4_6__2016_9_15_16_12_21_mouseData.csv
# Rows loaded: 584
# 2 processed files.
# **-Participant:6MDH09
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 6MDH09
# .\rawData/6MDH09__86_e_0_9__2016_9_15_12_40_51_mouseData.csv
# Rows loaded: 568
# .\rawData/6MDH09__87_e_3_9__2016_9_15_12_49_45_mouseData.csv
# Rows loaded: 1158
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 6MDH09
# .\rawData/6MDH09__90_c_0_9__2016_9_15_13_1_54_mouseData.csv
# Rows loaded: 1216
# .\rawData/6MDH09__91_c_4_9__2016_9_15_13_8_56_mouseData.csv
# Rows loaded: 4376
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 6MDH09
# .\rawData/6MDH09__84_s_0_9__2016_9_15_12_28_46_mouseData.csv
# Rows loaded: 774
# .\rawData/6MDH09__85_s_2_9__2016_9_15_12_37_3_mouseData.csv
# Rows loaded: 1845
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 6MDH09
# .\rawData/6MDH09__88_n_0_9__2016_9_15_12_53_56_mouseData.csv
# Rows loaded: 478
# .\rawData/6MDH09__89_n_1_9__2016_9_15_13_0_21_mouseData.csv
# Rows loaded: 998
# 2 processed files.
# **-Participant:13MM08
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 13MM08
# .\rawData/13MM08__111_e_0_8__2016_9_16_12_33_39_mouseData.csv
# Rows loaded: 441
# .\rawData/13MM08__112_e_4_8__2016_9_16_12_40_40_mouseData.csv
# Rows loaded: 916
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 13MM08
# .\rawData/13MM08__109_c_0_8__2016_9_16_12_24_54_mouseData.csv
# Rows loaded: 1212
# .\rawData/13MM08__110_c_1_8__2016_9_16_12_31_4_mouseData.csv
# Rows loaded: 2839
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 13MM08
# .\rawData/13MM08__107_s_0_8__2016_9_16_12_14_57_mouseData.csv
# Rows loaded: 3287
# .\rawData/13MM08__108_s_2_8__2016_9_16_12_22_12_mouseData.csv
# Rows loaded: 8379
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 13MM08
# .\rawData/13MM08__113_n_0_8__2016_9_16_12_42_26_mouseData.csv
# Rows loaded: 455
# .\rawData/13MM08__114_n_3_8__2016_9_16_12_48_45_mouseData.csv
# Rows loaded: 2691
# 2 processed files.
# **-Participant:12JR11
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 12JR11
# .\rawData/12JR11__102_e_4_11__2016_9_16_10_11_51_mouseData.csv
# Rows loaded: 641
# 1 processed files.
# C:\Users\xz32\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:24: UserWarning: Warning!!: I should be finding two files for participant:12JR11 and condition:e and I'm getting less.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 12JR11
# .\rawData/12JR11__105_c_0_11__2016_9_16_10_27_26_mouseData.csv
# Rows loaded: 1579
# .\rawData/12JR11__106_c_3_11__2016_9_16_10_37_6_mouseData.csv
# Rows loaded: 4577
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 12JR11
# .\rawData/12JR11__103_s_0_11__2016_9_16_10_14_19_mouseData.csv
# Rows loaded: 472
# .\rawData/12JR11__104_s_1_11__2016_9_16_10_25_33_mouseData.csv
# Rows loaded: 1376
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 12JR11
# .\rawData/12JR11__100_n_0_11__2016_9_16_9_48_56_mouseData.csv
# Rows loaded: 502
# .\rawData/12JR11__101_n_2_11__2016_9_16_9_58_30_mouseData.csv
# Rows loaded: 1545
# 2 processed files.
# **-Participant:10F
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 10F
# .\rawData/10F__172_e_0_10__2016_12_13_15_56_30_mouseData.csv
# Rows loaded: 2675
# .\rawData/10F__173_e_3_10__2016_12_13_16_9_52_mouseData.csv
# Rows loaded: 9697
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 10F
# .\rawData/10F__174_c_0_10__2016_12_13_16_17_24_mouseData.csv
# Rows loaded: 4970
# .\rawData/10F__175_c_4_10__2016_12_13_16_32_22_mouseData.csv
# Rows loaded: 9472
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 10F
# .\rawData/10F__170_s_0_10__2016_12_13_15_35_51_mouseData.csv
# Rows loaded: 4218
# .\rawData/10F__171_s_2_10__2016_12_13_15_49_13_mouseData.csv
# Rows loaded: 17850
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 10F
# .\rawData/10F__176_n_0_10__2016_12_13_16_36_13_mouseData.csv
# Rows loaded: 2329
# .\rawData/10F__177_n_1_10__2016_12_13_16_50_10_mouseData.csv
# Rows loaded: 7686
# 2 processed files.
# **-Participant:17MRW13
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 17MRW13
# .\rawData/17MRW13__135_e_0_13__2016_9_19_11_16_37_mouseData.csv
# Rows loaded: 383
# .\rawData/17MRW13__136_e_2_13__2016_9_19_11_23_7_mouseData.csv
# Rows loaded: 1693
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 17MRW13
# .\rawData/17MRW13__133_c_0_13__2016_9_19_11_5_6_mouseData.csv
# Rows loaded: 2094
# .\rawData/17MRW13__134_c_1_13__2016_9_19_11_11_42_mouseData.csv
# Rows loaded: 4200
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 17MRW13
# .\rawData/17MRW13__137_s_0_13__2016_9_19_11_25_14_mouseData.csv
# Rows loaded: 488
# .\rawData/17MRW13__138_s_4_13__2016_9_19_11_32_52_mouseData.csv
# Rows loaded: 3191
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 17MRW13
# .\rawData/17MRW13__131_n_0_13__2016_9_19_10_56_5_mouseData.csv
# Rows loaded: 1240
# .\rawData/17MRW13__132_n_3_13__2016_9_19_11_2_34_mouseData.csv
# Rows loaded: 1255
# 2 processed files.
# **-Participant:12F
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 12F
# .\rawData/12F__188_e_0_12__2016_12_15_11_2_35_mouseData.csv
# Rows loaded: 2291
# .\rawData/12F__189_e_4_12__2016_12_15_11_13_16_mouseData.csv
# Rows loaded: 1914
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 12F
# .\rawData/12F__190_c_0_12__2016_12_15_11_18_53_mouseData.csv
# Rows loaded: 916
# .\rawData/12F__191_c_3_12__2016_12_15_11_26_37_mouseData.csv
# Rows loaded: 2638
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 12F
# .\rawData/12F__192_s_0_12__2016_12_15_11_30_41_mouseData.csv
# Rows loaded: 401
# .\rawData/12F__193_s_1_12__2016_12_15_11_37_41_mouseData.csv
# Rows loaded: 2243
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 12F
# .\rawData/12F__186_n_0_12__2016_12_15_10_41_14_mouseData.csv
# Rows loaded: 653
# .\rawData/12F__187_n_2_12__2016_12_15_10_54_6_mouseData.csv
# Rows loaded: 3669
# 2 processed files.
# **-Participant:MPS15
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: MPS15
# .\rawData/MPS15__153_e_0_15__2016_9_19_14_3_15_mouseData.csv
# Rows loaded: 411
# .\rawData/MPS15__154_e_4_15__2016_9_19_14_9_0_mouseData.csv
# Rows loaded: 1308
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: MPS15
# .\rawData/MPS15__147_c_0_15__2016_9_19_13_42_21_mouseData.csv
# Rows loaded: 1259
# .\rawData/MPS15__148_c_3_15__2016_9_19_13_47_31_mouseData.csv
# Rows loaded: 1644
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: MPS15
# .\rawData/MPS15__149_s_0_15__2016_9_19_13_49_0_mouseData.csv
# Rows loaded: 666
# .\rawData/MPS15__150_s_2_15__2016_9_19_13_55_26_mouseData.csv
# Rows loaded: 2356
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: MPS15
# .\rawData/MPS15__151_n_0_15__2016_9_19_13_56_22_mouseData.csv
# Rows loaded: 480
# .\rawData/MPS15__152_n_1_15__2016_9_19_14_1_48_mouseData.csv
# Rows loaded: 2536
# 2 processed files.
# **-Participant:2FQ2014
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 2FQ2014
# .\rawData/2FQ2014__32_e_0_14__2016_6_17_14_51_45_mouseData.csv
# Rows loaded: 260
# .\rawData/2FQ2014__33_e_2_14__2016_6_17_15_0_13_mouseData.csv
# Rows loaded: 782
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 2FQ2014
# .\rawData/2FQ2014__28_c_0_14__2016_6_17_14_27_57_mouseData.csv
# Rows loaded: 2012
# .\rawData/2FQ2014__29_c_1_14__2016_6_17_14_35_57_mouseData.csv
# Rows loaded: 2242
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 2FQ2014
# .\rawData/2FQ2014__30_s_0_14__2016_6_17_14_39_22_mouseData.csv
# Rows loaded: 555
# .\rawData/2FQ2014__31_s_4_14__2016_6_17_14_47_54_mouseData.csv
# Rows loaded: 1211
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 2FQ2014
# .\rawData/2FQ2014__26_n_0_14__2016_6_17_14_15_52_mouseData.csv
# Rows loaded: 576
# .\rawData/2FQ2014__27_n_3_14__2016_6_17_14_23_10_mouseData.csv
# Rows loaded: 945
# 2 processed files.
# **-Participant:5MS17
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 5MS17
# .\rawData/5MS17__66_e_0_17__2016_7_8_13_38_41_mouseData.csv
# Rows loaded: 586
# .\rawData/5MS17__67_e_2_17__2016_7_8_13_45_39_mouseData.csv
# Rows loaded: 718
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 5MS17
# .\rawData/5MS17__64_c_0_17__2016_7_8_13_26_16_mouseData.csv
# Rows loaded: 485
# .\rawData/5MS17__65_c_1_17__2016_7_8_13_34_48_mouseData.csv
# Rows loaded: 1623
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 5MS17
# .\rawData/5MS17__62_s_0_17__2016_7_8_13_14_0_mouseData.csv
# Rows loaded: 588
# .\rawData/5MS17__63_s_4_17__2016_7_8_13_22_11_mouseData.csv
# Rows loaded: 1036
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 5MS17
# .\rawData/5MS17__60_n_0_17__2016_7_8_13_2_21_mouseData.csv
# Rows loaded: 979
# .\rawData/5MS17__61_n_3_17__2016_7_8_13_9_6_mouseData.csv
# Rows loaded: 920
# 2 processed files.
# **-Participant:2FS2116
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 2FS2116
# .\rawData/2FS2116__46_e_0_16__2016_6_20_16_45_16_mouseData.csv
# Rows loaded: 247
# .\rawData/2FS2116__47_e_4_16__2016_6_20_16_57_14_mouseData.csv
# Rows loaded: 716
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 2FS2116
# .\rawData/2FS2116__42_c_0_16__2016_6_20_16_16_29_mouseData.csv
# Rows loaded: 3525
# .\rawData/2FS2116__43_c_3_16__2016_6_20_16_25_25_mouseData.csv
# Rows loaded: 3172
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 2FS2116
# .\rawData/2FS2116__44_s_0_16__2016_6_20_16_29_41_mouseData.csv
# Rows loaded: 582
# .\rawData/2FS2116__45_s_2_16__2016_6_20_16_41_43_mouseData.csv
# Rows loaded: 1123
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 2FS2116
# .\rawData/2FS2116__48_n_0_16__2016_6_20_16_59_59_mouseData.csv
# Rows loaded: 475
# .\rawData/2FS2116__49_n_1_16__2016_6_20_17_10_16_mouseData.csv
# Rows loaded: 949
# 2 processed files.
# **-Participant:18MDM19
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 18MDM19
# .\rawData/18MDM19__143_e_0_19__2016_9_19_12_40_56_mouseData.csv
# Rows loaded: 497
# .\rawData/18MDM19__144_e_2_19__2016_9_19_12_50_24_mouseData.csv
# Rows loaded: 889
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 18MDM19
# .\rawData/18MDM19__145_c_0_19__2016_9_19_12_52_54_mouseData.csv
# Rows loaded: 2269
# .\rawData/18MDM19__146_c_3_19__2016_9_19_13_2_52_mouseData.csv
# Rows loaded: 3974
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 18MDM19
# .\rawData/18MDM19__139_s_0_19__2016_9_19_12_16_50_mouseData.csv
# Rows loaded: 833
# .\rawData/18MDM19__140_s_4_19__2016_9_19_12_26_27_mouseData.csv
# Rows loaded: 1323
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 18MDM19
# .\rawData/18MDM19__141_n_0_19__2016_9_19_12_29_4_mouseData.csv
# Rows loaded: 597
# .\rawData/18MDM19__142_n_1_19__2016_9_19_12_37_31_mouseData.csv
# Rows loaded: 615
# 2 processed files.
# **-Participant:18F
# ----Condition:e
# Loading file of type: mouseData, condition: e , participant: 18F
# .\rawData/18F__182_e_0_18__2016_12_14_16_17_18_mouseData.csv
# Rows loaded: 586
# .\rawData/18F__183_e_2_18__2016_12_14_16_30_51_mouseData.csv
# Rows loaded: 891
# 2 processed files.
# ----Condition:c
# Loading file of type: mouseData, condition: c , participant: 18F
# .\rawData/18F__184_c_0_18__2016_12_14_16_39_58_mouseData.csv
# Rows loaded: 1995
# .\rawData/18F__185_c_1_18__2016_12_14_16_56_52_mouseData.csv
# Rows loaded: 8551
# 2 processed files.
# ----Condition:s
# Loading file of type: mouseData, condition: s , participant: 18F
# .\rawData/18F__180_s_0_18__2016_12_14_15_52_51_mouseData.csv
# Rows loaded: 889
# .\rawData/18F__181_s_4_18__2016_12_14_16_8_19_mouseData.csv
# Rows loaded: 2577
# 2 processed files.
# ----Condition:n
# Loading file of type: mouseData, condition: n , participant: 18F
# .\rawData/18F__178_n_0_18__2016_12_14_15_25_43_mouseData.csv
# Rows loaded: 1031
# .\rawData/18F__179_n_3_18__2016_12_14_15_44_25_mouseData.csv
# Rows loaded: 3109
# 2 processed files.

# %%
for row in interactionMeasures:
    print(row)
    
interactionMeasures
# Out:
# M14
# M15
# M15m
# M15o
# M15t
# M16
# M16m
# M16o
# M16t
# M17
# country
# experimentNumber
# orderNumber
# training
# type
# userId
#         M14  M15  M15m  M15o  M15t            M16           M16m  \
# 0      1699    1     0     1     0          49597            171
# 1     16073    1     0     1     0         282589              0
# 2      2021    1     0     1     0         125074              0
# 3     10035    3     0     1     2         289551             50
# 4      3914    1     0     0     1 -1474041058073            136
# 5    236674    0     0     0     0 -1474040880184 -1474041169363
# 6      2093    0     0     0     0          18039              0
# 7     10721    2     0     0     2 -1474040351958              0
# 8      1118    1     0     0     1          12395           1675
# 9     51271    1     0     1     0         500619             64
# 10     2533    0     0     0     0          54660              0
# 11   284439    0     0     0     0         430214              0
# 12    75935    1     0     0     1 -1474293280295              0
# 13   300345    2     1     1     0 -1474293277375 -1474293656814
# 14    48159    1     0     0     1 -1474294169546              0
# 15    29360    1     0     0     1 -1474293989419              0
# 16     1878    1     0     0     1          60760              0
# 17     6464    1     0     0     1         262437              0
# 18    43946    0     0     0     0         119692              0
# 19    10115    1     0     0     1         298543              0
# 20     8104    1     1     0     0          44612           3990
# 21    25959    1     0     1     0         352588            512
# 22     2784    1     0     0     1          38787              0
# 23    10692    1     0     0     1         321055              0
# 24    23014    0     0     0     0         102984              0
# 25   410744    1     0     0     1         890636              0
# 26    60862    3     0     0     3         214884              0
# 27    21650    4     0     1     3         818860              0
# 28     2742    0     0     0     0          20176           2977
# 29    36019    1     0     0     1         611323           2991
# ..      ...  ...   ...   ...   ...            ...            ...
# 160     819    1     0     0     1          12551              0
# 161    9544    3     0     1     2         355645            312
# 162    4014    1     0     0     1          92391           1015
# 163   16709    3     0     1     2         307615           2323
# 164    2394    4     0     2     2         122317              0
# 165    8598    3     0     1     2 -1467979179069              0
# 166    1348    1     0     0     1          88074              0
# 167   20729    1     0     0     1         541126            262
# 168    3458    0     0     0     0         126194              0
# 169    9348    1     0     0     1         358100              0
# 170    7439    1     0     0     1 -1466436297925           3810
# 171   20314    3     0     3     0         529421              0
# 172    2102    1     0     0     1          33584              0
# 173   10156    1     0     1     0         467667              0
# 174    2477    2     0     0     2          72360              0
# 175    9578    2     0     0     2         423964              0
# 176    1269    4     0     2     2          65977              0
# 177    8706    3     0     1     2         483912              0
# 178    7074    1     1     0     0 -1474283500487 -1474283596807
# 179   26126    2     0     1     1         429863           3776
# 180    2482    1     0     0     1          61013              0
# 181   10136    2     0     1     1         347439              0
# 182   47861    0     0     0     0         161342              0
# 183  233146    0     0     0     0         533334              0
# 184    8969    0     0     0     0         233990              0
# 185   29398    0     0     0     0         691973              0
# 186    3367    1     1     0     0         254157           6003
# 187   26516    5     1     1     3         653189          15651
# 188    2543    4     0     1     3         314535              0
# 189    9845    2     0     1     1         654882              0
#
#               M16o           M16t           M17  country  experimentNumber  \
# 0            48924            502   2239.671620        0               125
# 1            53137         229452   5999.696358        3               126
# 2            27119          97955   5165.991806        0               123
# 3            16641         272860   8162.465534        4               124
# 4   -1474041064902           6693   5225.228176        0               129
# 5           212948          76231  11077.388050        1               130
# 6              700          17339   1955.446455        0               127
# 7   -1474040576914         224956   7792.194569        2               128
# 8             3446           7274   4454.201258        0               161
# 9           201270         299285  14660.148175        2               162
# 10            4473          50187   6329.638928        0               159
# 11           30684         399530   7779.003238        3               160
# 12          100182 -1474293380477  12364.182292        0               155
# 13          361231          18208  17734.793082        4               156
# 14           72048 -1474294241594  11562.813950        0               157
# 15          244359 -1474294233778  16672.645918        1               158
# 16             687          60073   2168.840997        0                40
# 17          109447         152990   6167.115947        3                41
# 18            8302         111390   7062.827400        0                34
# 19            6079         292464   6629.610187        4                35
# 20           39886            736   5029.264226        0                38
# 21          350757           1319  11588.619554        1                39
# 22           37271           1516   1980.036832        0                36
# 23          291727          29328   5612.218171        2                37
# 24           62302          40682   2405.391295        0               198
# 25          265724         624912  21802.657353        3               199
# 26            3174         211710   5414.759828        0               194
# 27           44218         774642  22500.434127        4               195
# 28           10509           6690   5229.185314        0               200
# 29          500101         108231  33879.464317        1               201
# ..             ...            ...           ...      ...               ...
# 160           1236          11315   3432.552311        0                64
# 161          16675         338658  11325.010067        1                65
# 162          89268           2108   5755.878917        0                62
# 163         292738          12554  11652.518684        4                63
# 164          89287          33030   7162.406495        0                60
# 165 -1467979226399          47330   7053.746077        3                61
# 166            580          87494   1716.474119        0                46
# 167         538940           1924   6432.246589        4                47
# 168           9491         116703  13461.796826        0                42
# 169         337670          20430   7817.989405        3                43
# 170         109888 -1466436411623   4536.063779        0                44
# 171         528997            424  10250.935788        2                45
# 172          30248           3336   3233.146791        0                48
# 173         466474           1193   7022.713886        1                49
# 174           6616          65744   2878.784410        0               143
# 175         363702          60262   5977.043285        2               144
# 176           5666          60311   4557.257246        0               145
# 177          16391         467521   9675.025930        3               146
# 178          95174           1146   5383.016130        0               139
# 179         422398           3689  11465.505435        4               140
# 180          51753           9260   3077.571994        0               141
# 181         344438           3001   5729.584321        1               142
# 182           1025         160317   3613.697734        0               182
# 183          75793         457541   6525.969125        2               183
# 184          72016         161974   6666.265803        0               184
# 185         112504         579469  22117.916181        1               185
# 186         246914           1240   6936.743128        0               180
# 187         625098          12440  29704.064434        4               181
# 188         270792          43743   4769.738949        0               178
# 189         532282         122600  10628.527982        3               179
#
#      orderNumber training type   userId
# 0             24    False    e   15FM24
# 1             24    False    e   15FM24
# 2             24    False    c   15FM24
# 3             24    False    c   15FM24
# 4             24    False    s   15FM24
# 5             24    False    s   15FM24
# 6             24    False    n   15FM24
# 7             24    False    n   15FM24
# 8             20    False    e  21MDC20
# 9             20    False    e  21MDC20
# 10            20    False    c  21MDC20
# 11            20    False    c  21MDC20
# 12            20    False    s  21MDC20
# 13            20    False    s  21MDC20
# 14            20    False    n  21MDC20
# 15            20    False    n  21MDC20
# 16            21    False    e  3MW2421
# 17            21    False    e  3MW2421
# 18            21    False    c  3MW2421
# 19            21    False    c  3MW2421
# 20            21    False    s  3MW2421
# 21            21    False    s  3MW2421
# 22            21    False    n  3MW2421
# 23            21    False    n  3MW2421
# 24            22    False    e      22F
# 25            22    False    e      22F
# 26            22    False    c      22F
# 27            22    False    c      22F
# 28            22    False    s      22F
# 29            22    False    s      22F
# ..           ...      ...  ...      ...
# 160           17    False    c    5MS17
# 161           17    False    c    5MS17
# 162           17    False    s    5MS17
# 163           17    False    s    5MS17
# 164           17    False    n    5MS17
# 165           17    False    n    5MS17
# 166           16    False    e  2FS2116
# 167           16    False    e  2FS2116
# 168           16    False    c  2FS2116
# 169           16    False    c  2FS2116
# 170           16    False    s  2FS2116
# 171           16    False    s  2FS2116
# 172           16    False    n  2FS2116
# 173           16    False    n  2FS2116
# 174           19    False    e  18MDM19
# 175           19    False    e  18MDM19
# 176           19    False    c  18MDM19
# 177           19    False    c  18MDM19
# 178           19    False    s  18MDM19
# 179           19    False    s  18MDM19
# 180           19    False    n  18MDM19
# 181           19    False    n  18MDM19
# 182           18    False    e      18F
# 183           18    False    e      18F
# 184           18    False    c      18F
# 185           18    False    c      18F
# 186           18    False    s      18F
# 187           18    False    s      18F
# 188           18    False    n      18F
# 189           18    False    n      18F
#
# [190 rows x 16 columns]
