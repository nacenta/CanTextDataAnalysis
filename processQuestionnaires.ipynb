# %% [markdown]
# # Process Questionnaires
# ## Imports and Global Setup

# %%
from __future__ import print_function, division
# %matplotlib inline

import sys 

def add_module_path(module_path):
    if module_path not in sys.path:
        sys.path.append(module_path)

add_module_path("../colour/")
add_module_path("../PyEDF/")

import numpy as np
import pandas as pd
import re
import os
import warnings
import math
import fileinput

from matplotlib import pyplot as plt
import scikits.bootstrap as boot

from operator import itemgetter

# import pyedf
# import conf

pd.options.display.mpl_style = 'default'

plt.rcParams['figure.figsize'] = (16.0, 10.0)
plt.set_cmap('gnuplot2')
# Out:
# C:\Users\xz32\AppData\Local\Continuum\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2881: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## Global Constants

# %%
# path = './DataDummy'
#path = r'G:\Miguel\Research\Research-Current\CMOS\Git Experiment Only\Logs (For test analysis)'
path = r'.\rawData'
#participant_ids = [ 'None', 'Johanas' ]
participant_ids =  [ '15FM24',
                     '21MDC20',
                     '3MW2421',
                     '22F',
                     '14JG23',
                     '1MQ2201',
                     '2ML3603',
                     '8FC02',
                     '5MS3205',
                     '9FH04',
                     '1MW2207',
                     '12FRH06',
                     '6MDH09',
                     '13MM08',
                     '12JR11',
                     '10F',
                     '17MRW13',
                     '12F',
                     'MPS15',
                     '2FQ2014',
                     '5MS17',
                     '2FS2116',
                     '18MDM19',
                     '18F']
condition_ids = ['e', 'c', 's', 'n']
#condition_ids = ['e', 'c']
mediaObjectsPerDocument = 20 # this comes from how the documents were set up.
mediaObjectsScotland = 4 # this comes from how the documents were set up.

# %% [markdown]
# # Utility Functions

# %%
def loadFileOfParticipantConditionLogtype(path,participantID,condition,logTypeEnding):
# Selects and loads a file from a participantID, of a given condition, of a particular type    
    regular_expression = str(participantID)+"__\S+_"+condition+"\S*"+logTypeEnding+".csv"
    filere = re.compile(regular_expression)
    frames = []
    numProcessedFiles = 0;    
    print('Loading file of type: '+logTypeEnding+", condition: "+condition+" , participant: "+participantID)
    for filename in os.listdir(path):      
        filematch = filere.match(filename)
        if filematch:
            filepath = path+'/'+filename
            print(filepath)
            
            # This next bit is necessary because there were (escaped) commas in some of the questions
            # Read in the file
            filedata = None
            with open(filepath, 'r') as file :
                filedata = file.read()
            # Replace the target string
            filedata = filedata.replace('\,', '')
            # Write the file out again
            with open(filepath, 'w') as file:
                file.write(filedata)

            frame = pd.read_csv(filepath,delimiter=',',engine="python",header=0)
            print("Rows loaded: "+str(len(frame.index)))  
            frames.append(frame)            
            numProcessedFiles += 1;
        #else:
            #print("Tried to match: "+filename)
            #print("With RE: "+regular_expression)
    print(str(numProcessedFiles)+" processed files.")
    if (numProcessedFiles > 2):
        warnings.warn("Warning!!: I'm getting more than two files for the same participant and the same condition. Clash in ID's?")
    elif (numProcessedFiles < 2):
        warnings.warn("Warning!!: I should be finding two files for participant:"+participantID+" and condition:"+condition+" and I'm getting less.")
    return frames

def loadPostQuestionnaire(path,participantID):
# Loads the PostQuestionnaire file for a given participant into a frame
    
    try:
        filepath = path+'/'+participantID+'_Post_Questionnaire.csv'
        frame = pd.read_csv(filepath,delimiter=',',engine="python",header=0)
        return frame
        
    except IOError:
        print("I could not find the Post-questionnaire for participant: "+participantID)
        return None
        
        

def cleanSpacesInColumns(frame):
    columns = frame.columns
    newColumns = []
    ix = 0
    for columnName in columns:
        newColumns.append(columnName.strip(' \n\t'))
        ix += 1
    frame.columns = newColumns
    return frame

# From: http://stackoverflow.com/questions/6987285/python-find-the-item-with-maximum-occurrences
# Ned Deili
def max_occurrences(seq):
    c = dict()
    for item in seq:
        c[item] = c.get(item, 0) + 1
    return max(c.iteritems(), key=itemgetter(1))

# %% [markdown]
# ## Processing data functions

# %%
def processRawQuestionnaire(rawFrame,framePostQuestionnaire):
    
    frame = cleanSpacesInColumns(rawFrame)
    
    # Prepare the output of this function: it's a dictionary
    values = {}
    valueMeanings = {}
    
    values['userId'] = frame.iloc[0].userId
    valueMeanings['userId'] = 'the identification number of the user'
    values['type'] = frame.iloc[0].type
    valueMeanings['type'] = 'the type of trial, i.e., the condition. One of (e=eyecantext, c=cantext, s=static, n=no-images)'
    values['country'] = frame.iloc[0].country
    valueMeanings['country'] = 'the document the trial was done in. One of (0=Scotland(training), 1=Laos, 2=Vanuatu, 3=Suriname, 4=Equatorial Guinea)'
    values['orderNumber'] = frame.iloc[0].orderNumber
    valueMeanings['orderNumber'] = 'the id of the order in which participants faced the conditions and the documents. Goes from 0 to 23'
    values['experimentNumber'] = frame.iloc[0].experimentNumber
    valueMeanings['experimentNumber'] = 'to be completed'
    values['training'] = frame.iloc[0].training
    valueMeanings['experimentNumber'] = 'whether this data comes from training or not'
    
    rightAnswers = 0 # counter for the correct answers
    numberOfQuestions = 0 # counter for the number of questions
    
    # The file contains two kinds of questions. The Subjective TLX is processed by finding
    # a corresponding text in the question (e.g., mental demand)
    # The rest of the questions are the quiz
    for i in range(0,(frame.shape[0]-1)):
        #print(frame.iloc[i])
        if ("Mental Demand" in frame.iloc[i].question):
            values['M18'] = frame.iloc[i].userAnswer
            valueMeanings['M18'] = "Subjective Mental Demand"
        elif ("Physical Demand" in frame.iloc[i].question):
            values['M19'] = frame.iloc[i].userAnswer
            valueMeanings['M19'] = "Subjective Physical Demand"
        elif ("Temporal Demand" in frame.iloc[i].question):
            values['M20'] = frame.iloc[i].userAnswer
            valueMeanings['M20'] = "Subjective Temporal Demand"
        elif ("Performance " in frame.iloc[i].question):
            values['M21'] = frame.iloc[i].userAnswer
            valueMeanings['M21'] = "Subjective Performance"
        elif ("Effort" in frame.iloc[i].question):
            values['M22'] = frame.iloc[i].userAnswer
            valueMeanings['M22'] = "Subjective Effort"
        elif ("Frustration" in frame.iloc[i].question):
            values['M23'] = frame.iloc[i].userAnswer
            valueMeanings['M23'] = "Subjective Frustration"        
        else:
            if (not(frame.iloc[i].userAnswer == '')):
                if (frame.iloc[i].correctAnswer == frame.iloc[i].userAnswer): # the answer is correct
                    rightAnswers += 1 
                numberOfQuestions += 1 # and we are processing this question
                
    values['M1'] = rightAnswers/numberOfQuestions
    valueMeanings['M1'] = "Proportion of correct answers of immediate test"
    
    # Here we start processing the results from the next day questionnaire
    if not(framePostQuestionnaire is None): # Only process this if the post-questionnaire exists
    
        #print(framePostQuestionnaire)
        myType = values['type'][0]
        #print("  Condition: "+myType)
        
        myCountryCode = values['country']
        #print("  Country: "+str(myCountryCode))
        
        myCountryLetters = ""
        if (myCountryCode == 0): # These are training (scotland) so we leave them blank
            myCountryLetters = ""
        elif (myCountryCode == 1):
            myCountryLetters = "lao"
        elif (myCountryCode == 2):
            myCountryLetters = "van"
        elif (myCountryCode == 3):
            myCountryLetters = "sur"
        elif (myCountryCode == 4):
            myCountryLetters = "equ"
        else:
            warnings.warn("Warning!!: Code for country out of range")

        print("  Countrylet: "+myCountryLetters)
            
        
        # Correct answered questions
        values['M2'] = framePostQuestionnaire['QD2_'+myType][0]/8
        valueMeanings['M2'] = 'Proportion of correct answers of next-day test - Note: only one measure of correctness for several questions'            
        
        # Distracting statement
        values['M24'] = framePostQuestionnaire['PT_distracting_'+myType][0]
        valueMeanings['M24'] = 'Distracting - 1 to 20, with 20 most distracting'            

        # Ignorable statement
        values['M25'] = framePostQuestionnaire['PT_ignorable_'+myType][0]
        valueMeanings['M25'] = 'Ignorable - 1 to 20, with 20 most ignorable'            

        # Usefulness statement
        values['M26'] = framePostQuestionnaire['PT_useful_'+myType][0]
        valueMeanings['M26'] = 'Useful - 1 to 20, with 20 most useful'            
        
        # Perception of learning
        values['M30'] = framePostQuestionnaire['LQ_'+myType][0]/8
        valueMeanings['M30'] = 'How much the participant thought the had learnt - 1 to 20, with 20 most useful'            
        
        # Note: 27 and 28 were removed 
        
        # Preference ranking
        values['M29'] = framePostQuestionnaire['PT_pref_'+myType][0]
        valueMeanings['M29'] = 'Ranking in overal preference (1 to 4 among all conditions)'
        
        if (myCountryLetters != ""): # Verification of redundancy (country vs condition indexing)
            values['M2country'] = framePostQuestionnaire['QD2_'+myCountryLetters][0]/8
            valueMeanings['M2country'] = 'This has to be equal to M2 - just indexed by country'                        
        
            values['M30country'] = framePostQuestionnaire['LQ_'+myCountryLetters][0]/8
            valueMeanings['M30country'] = 'This has to be equal to M30 - just indexed by country'                        
        
            if (values['M2country'] != values['M2']):
                warnings.warn("Warning!!: M2 inconsistent between condition and country")
                
            if (values['M30country'] != values['M30']):
                warnings.warn("Warning!!: M30 inconsistent between condition and country")
                
    
    return [values, valueMeanings]

# %% [markdown]
# ## Main collection of data

# %%
# Gather Data Metrics
questionnaireDataRows = []
questionnaireDataMeanings = []
rowCount = 0
for participantID in participant_ids:
    print('**-Participant:'+participantID)
    frame_post_questionnaire = loadPostQuestionnaire(path,participantID)
    for conditionID in condition_ids:
        print('----Condition:'+conditionID)
        frames = loadFileOfParticipantConditionLogtype(path,
                                                           participantID,
                                                           conditionID,
                                                           'questionare')
        len(frames)
        for frame in frames:
            processedDataRows = processRawQuestionnaire(frame,frame_post_questionnaire)
            # print('len of processed data rows:'+str(len(processedDataRows)))
            questionnaireDataRows.append(processedDataRows[0])
            rowCount += 1
            # print('rowCount:'+str(rowCount))
            if (len(questionnaireDataMeanings) == 0):
                questionnaireDataMeanings = processedDataRows[1]

questionnaireMeasures = pd.DataFrame(questionnaireDataRows)
questionnaireMeasures.to_pickle(r'.\processedData\TLX_and_Questions_AnalysisResults_pandas.pddf')
questionnaireMeasures.to_csv(r'.\processedData\TLX_and_Questions_AnalysisResults.csv')
# Out:
# **-Participant:15FM24
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 15FM24
# .\rawData/15FM24__125_e_0_24__2016_9_16_16_33_8_questionare.csv
# Rows loaded: 11
# .\rawData/15FM24__126_e_3_24__2016_9_16_16_41_0_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 15FM24
# .\rawData/15FM24__123_c_0_24__2016_9_16_16_22_3_questionare.csv
# Rows loaded: 11
# .\rawData/15FM24__124_c_4_24__2016_9_16_16_30_41_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 15FM24
# .\rawData/15FM24__129_s_0_24__2016_9_16_16_52_11_questionare.csv
# Rows loaded: 11
# .\rawData/15FM24__130_s_1_24__2016_9_16_17_0_40_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 15FM24
# .\rawData/15FM24__127_n_0_24__2016_9_16_16_42_57_questionare.csv
# Rows loaded: 11
# .\rawData/15FM24__128_n_2_24__2016_9_16_16_49_50_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# **-Participant:21MDC20
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 21MDC20
# .\rawData/21MDC20__161_e_0_20__2016_9_19_15_36_30_questionare.csv
# Rows loaded: 11
# .\rawData/21MDC20__162_e_2_20__2016_9_19_15_47_6_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 21MDC20
# .\rawData/21MDC20__159_c_0_20__2016_9_19_15_24_51_questionare.csv
# Rows loaded: 11
# .\rawData/21MDC20__160_c_3_20__2016_9_19_15_34_44_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 21MDC20
# .\rawData/21MDC20__155_s_0_20__2016_9_19_14_59_38_questionare.csv
# Rows loaded: 11
# .\rawData/21MDC20__156_s_4_20__2016_9_19_15_10_3_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 21MDC20
# .\rawData/21MDC20__157_n_0_20__2016_9_19_15_13_5_questionare.csv
# Rows loaded: 11
# .\rawData/21MDC20__158_n_1_20__2016_9_19_15_22_31_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# **-Participant:3MW2421
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 3MW2421
# .\rawData/3MW2421__40_e_0_21__2016_6_20_14_46_13_questionare.csv
# Rows loaded: 11
# .\rawData/3MW2421__41_e_3_21__2016_6_20_14_52_43_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 3MW2421
# .\rawData/3MW2421__34_c_0_21__2016_6_20_14_11_6_questionare.csv
# Rows loaded: 11
# .\rawData/3MW2421__35_c_4_21__2016_6_20_14_19_24_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 3MW2421
# .\rawData/3MW2421__38_s_0_21__2016_6_20_14_32_53_questionare.csv
# Rows loaded: 11
# .\rawData/3MW2421__39_s_1_21__2016_6_20_14_40_55_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 3MW2421
# .\rawData/3MW2421__36_n_0_21__2016_6_20_14_21_54_questionare.csv
# Rows loaded: 11
# .\rawData/3MW2421__37_n_2_21__2016_6_20_14_29_41_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# **-Participant:22F
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 22F
# .\rawData/22F__198_e_0_22__2016_12_15_16_4_58_questionare.csv
# Rows loaded: 11
# .\rawData/22F__199_e_3_22__2016_12_15_16_23_8_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 22F
# .\rawData/22F__194_c_0_22__2016_12_15_15_15_0_questionare.csv
# Rows loaded: 11
# .\rawData/22F__195_c_4_22__2016_12_15_15_32_3_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 22F
# .\rawData/22F__200_s_0_22__2016_12_15_16_27_32_questionare.csv
# Rows loaded: 11
# .\rawData/22F__201_s_1_22__2016_12_15_16_40_11_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 22F
# .\rawData/22F__196_n_0_22__2016_12_15_15_41_37_questionare.csv
# Rows loaded: 11
# .\rawData/22F__197_n_2_22__2016_12_15_15_57_39_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# **-Participant:14JG23
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 14JG23
# .\rawData/14JG23__115_e_0_23__2016_9_16_14_55_21_questionare.csv
# Rows loaded: 11
# .\rawData/14JG23__116_e_3_23__2016_9_16_15_4_4_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 14JG23
# .\rawData/14JG23__121_c_0_23__2016_9_16_15_37_46_questionare.csv
# Rows loaded: 11
# .\rawData/14JG23__122_c_4_23__2016_9_16_15_46_28_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 14JG23
# .\rawData/14JG23__117_s_0_23__2016_9_16_15_9_4_questionare.csv
# Rows loaded: 11
# .\rawData/14JG23__118_s_1_23__2016_9_16_15_22_4_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 14JG23
# .\rawData/14JG23__119_n_0_23__2016_9_16_15_26_2_questionare.csv
# Rows loaded: 11
# .\rawData/14JG23__120_n_2_23__2016_9_16_15_34_29_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# **-Participant:1MQ2201
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 1MQ2201
# .\rawData/1MQ2201__0_e_0_1__2016_1_22_15_28_42_questionare.csv
# Rows loaded: 11
# .\rawData/1MQ2201__1_e_1_1__2016_1_22_15_38_10_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 1MQ2201
# .\rawData/1MQ2201__2_c_0_1__2016_1_22_15_44_35_questionare.csv
# Rows loaded: 11
# .\rawData/1MQ2201__3_c_2_1__2016_1_22_15_54_41_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 1MQ2201
# .\rawData/1MQ2201__4_s_3_1__2016_1_22_16_13_24_questionare.csv
# Rows loaded: 15
# 1 processed files.
#   Countrylet: sur
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 1MQ2201
# .\rawData/1MQ2201__5_n_0_1__2016_1_22_16_17_18_questionare.csv
# Rows loaded: 11
# .\rawData/1MQ2201__6_n_4_1__2016_1_22_16_28_0_questionare.csv
# C:\Users\xz32\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:36: UserWarning: Warning!!: I should be finding two files for participant:1MQ2201 and condition:s and I'm getting less.
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# **-Participant:2ML3603
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 2ML3603
# .\rawData/2ML3603__7_e_0_3__2016_4_19_16_21_38_questionare.csv
# Rows loaded: 11
# .\rawData/2ML3603__8_e_1_3__2016_4_19_16_30_26_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 2ML3603
# .\rawData/2ML3603__11_c_0_3__2016_4_19_16_48_51_questionare.csv
# Rows loaded: 11
# .\rawData/2ML3603__12_c_2_3__2016_4_19_16_56_19_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 2ML3603
# .\rawData/2ML3603__10_s_3_3__2016_4_19_16_45_42_questionare.csv
# Rows loaded: 15
# .\rawData/2ML3603__9_s_0_3__2016_4_19_16_36_6_questionare.csv
# Rows loaded: 11
# 2 processed files.
#   Countrylet: sur
#   Countrylet:
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 2ML3603
# .\rawData/2ML3603__13_n_0_3__2016_4_19_16_59_22_questionare.csv
# Rows loaded: 11
# .\rawData/2ML3603__14_n_4_3__2016_4_19_17_7_16_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# **-Participant:8FC02
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 8FC02
# .\rawData/8FC02__68_e_0_2__2016_7_12_13_55_8_questionare.csv
# Rows loaded: 11
# .\rawData/8FC02__69_e_1_2__2016_7_12_14_8_39_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 8FC02
# .\rawData/8FC02__70_c_0_2__2016_7_12_14_11_58_questionare.csv
# Rows loaded: 11
# .\rawData/8FC02__71_c_2_2__2016_7_12_14_23_0_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 8FC02
# .\rawData/8FC02__74_s_0_2__2016_7_12_14_37_3_questionare.csv
# Rows loaded: 11
# .\rawData/8FC02__75_s_3_2__2016_7_12_14_46_3_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 8FC02
# .\rawData/8FC02__72_n_0_2__2016_7_12_14_25_47_questionare.csv
# Rows loaded: 11
# .\rawData/8FC02__73_n_4_2__2016_7_12_14_34_48_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# **-Participant:5MS3205
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 5MS3205
# .\rawData/5MS3205__52_e_0_5__2016_6_23_15_30_26_questionare.csv
# Rows loaded: 11
# .\rawData/5MS3205__53_e_1_5__2016_6_23_15_36_53_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 5MS3205
# .\rawData/5MS3205__56_c_0_5__2016_6_23_15_54_4_questionare.csv
# Rows loaded: 11
# .\rawData/5MS3205__57_c_2_5__2016_6_23_16_3_46_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 5MS3205
# .\rawData/5MS3205__58_s_0_5__2016_6_23_16_5_54_questionare.csv
# Rows loaded: 11
# .\rawData/5MS3205__59_s_3_5__2016_6_23_16_17_5_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 5MS3205
# .\rawData/5MS3205__54_n_0_5__2016_6_23_15_40_16_questionare.csv
# Rows loaded: 11
# .\rawData/5MS3205__55_n_4_5__2016_6_23_15_49_51_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# **-Participant:9FH04
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 9FH04
# .\rawData/9FH04__76_e_0_4__2016_7_12_15_38_34_questionare.csv
# Rows loaded: 11
# .\rawData/9FH04__77_e_1_4__2016_7_12_15_46_6_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 9FH04
# .\rawData/9FH04__82_c_0_4__2016_7_12_16_7_34_questionare.csv
# Rows loaded: 11
# .\rawData/9FH04__83_c_2_4__2016_7_12_16_13_3_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 9FH04
# .\rawData/9FH04__78_s_0_4__2016_7_12_15_50_6_questionare.csv
# Rows loaded: 11
# .\rawData/9FH04__79_s_3_4__2016_7_12_15_57_44_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 9FH04
# .\rawData/9FH04__80_n_0_4__2016_7_12_16_0_58_questionare.csv
# Rows loaded: 11
# .\rawData/9FH04__81_n_4_4__2016_7_12_16_5_21_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# **-Participant:1MW2207
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 1MW2207
# .\rawData/1MW2207__24_e_0_7__2016_6_15_15_33_19_questionare.csv
# Rows loaded: 11
# .\rawData/1MW2207__25_e_4_7__2016_6_15_15_43_1_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 1MW2207
# .\rawData/1MW2207__20_c_0_7__2016_6_15_15_10_6_questionare.csv
# Rows loaded: 11
# .\rawData/1MW2207__21_c_1_7__2016_6_15_15_20_31_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 1MW2207
# .\rawData/1MW2207__18_s_0_7__2016_6_15_14_55_38_questionare.csv
# Rows loaded: 11
# .\rawData/1MW2207__19_s_2_7__2016_6_15_15_5_18_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 1MW2207
# .\rawData/1MW2207__22_n_0_7__2016_6_15_15_22_47_questionare.csv
# Rows loaded: 11
# .\rawData/1MW2207__23_n_3_7__2016_6_15_15_30_40_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# **-Participant:12FRH06
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 12FRH06
# .\rawData/12FRH06__92_e_0_6__2016_9_15_15_53_49_questionare.csv
# Rows loaded: 11
# .\rawData/12FRH06__93_e_1_6__2016_9_15_16_1_16_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 12FRH06
# .\rawData/12FRH06__98_c_0_6__2016_9_15_16_28_37_questionare.csv
# Rows loaded: 11
# .\rawData/12FRH06__99_c_2_6__2016_9_15_16_37_26_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 12FRH06
# .\rawData/12FRH06__96_s_0_6__2016_9_15_16_16_30_questionare.csv
# Rows loaded: 11
# .\rawData/12FRH06__97_s_3_6__2016_9_15_16_25_56_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 12FRH06
# .\rawData/12FRH06__94_n_0_6__2016_9_15_16_3_41_questionare.csv
# Rows loaded: 11
# .\rawData/12FRH06__95_n_4_6__2016_9_15_16_12_21_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# **-Participant:6MDH09
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 6MDH09
# .\rawData/6MDH09__86_e_0_9__2016_9_15_12_40_51_questionare.csv
# Rows loaded: 11
# .\rawData/6MDH09__87_e_3_9__2016_9_15_12_49_45_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 6MDH09
# .\rawData/6MDH09__90_c_0_9__2016_9_15_13_1_54_questionare.csv
# Rows loaded: 11
# .\rawData/6MDH09__91_c_4_9__2016_9_15_13_8_56_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 6MDH09
# .\rawData/6MDH09__84_s_0_9__2016_9_15_12_28_46_questionare.csv
# Rows loaded: 11
# .\rawData/6MDH09__85_s_2_9__2016_9_15_12_37_3_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 6MDH09
# .\rawData/6MDH09__88_n_0_9__2016_9_15_12_53_56_questionare.csv
# Rows loaded: 11
# .\rawData/6MDH09__89_n_1_9__2016_9_15_13_0_21_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# **-Participant:13MM08
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 13MM08
# .\rawData/13MM08__111_e_0_8__2016_9_16_12_33_39_questionare.csv
# Rows loaded: 11
# .\rawData/13MM08__112_e_4_8__2016_9_16_12_40_40_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 13MM08
# .\rawData/13MM08__109_c_0_8__2016_9_16_12_24_54_questionare.csv
# Rows loaded: 11
# .\rawData/13MM08__110_c_1_8__2016_9_16_12_31_4_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 13MM08
# .\rawData/13MM08__107_s_0_8__2016_9_16_12_14_57_questionare.csv
# Rows loaded: 11
# .\rawData/13MM08__108_s_2_8__2016_9_16_12_22_12_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 13MM08
# .\rawData/13MM08__113_n_0_8__2016_9_16_12_42_26_questionare.csv
# Rows loaded: 11
# .\rawData/13MM08__114_n_3_8__2016_9_16_12_48_45_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# **-Participant:12JR11
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 12JR11
# .\rawData/12JR11__102_e_4_11__2016_9_16_10_11_51_questionare.csv
# Rows loaded: 15
# 1 processed files.
#   Countrylet: equ
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 12JR11
# .\rawData/12JR11__105_c_0_11__2016_9_16_10_27_26_questionare.csv
# Rows loaded: 11
# .\rawData/12JR11__106_c_3_11__2016_9_16_10_37_6_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
# C:\Users\xz32\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:36: UserWarning: Warning!!: I should be finding two files for participant:12JR11 and condition:e and I'm getting less.
#   Countrylet: sur
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 12JR11
# .\rawData/12JR11__103_s_0_11__2016_9_16_10_14_19_questionare.csv
# Rows loaded: 11
# .\rawData/12JR11__104_s_1_11__2016_9_16_10_25_33_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 12JR11
# .\rawData/12JR11__100_n_0_11__2016_9_16_9_48_56_questionare.csv
# Rows loaded: 11
# .\rawData/12JR11__101_n_2_11__2016_9_16_9_58_30_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# **-Participant:10F
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 10F
# .\rawData/10F__172_e_0_10__2016_12_13_15_56_30_questionare.csv
# Rows loaded: 11
# .\rawData/10F__173_e_3_10__2016_12_13_16_9_52_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 10F
# .\rawData/10F__174_c_0_10__2016_12_13_16_17_24_questionare.csv
# Rows loaded: 11
# .\rawData/10F__175_c_4_10__2016_12_13_16_32_22_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 10F
# .\rawData/10F__170_s_0_10__2016_12_13_15_35_51_questionare.csv
# Rows loaded: 11
# .\rawData/10F__171_s_2_10__2016_12_13_15_49_13_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 10F
# .\rawData/10F__176_n_0_10__2016_12_13_16_36_13_questionare.csv
# Rows loaded: 11
# .\rawData/10F__177_n_1_10__2016_12_13_16_50_10_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# **-Participant:17MRW13
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 17MRW13
# .\rawData/17MRW13__135_e_0_13__2016_9_19_11_16_37_questionare.csv
# Rows loaded: 11
# .\rawData/17MRW13__136_e_2_13__2016_9_19_11_23_7_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 17MRW13
# .\rawData/17MRW13__133_c_0_13__2016_9_19_11_5_6_questionare.csv
# Rows loaded: 11
# .\rawData/17MRW13__134_c_1_13__2016_9_19_11_11_42_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 17MRW13
# .\rawData/17MRW13__137_s_0_13__2016_9_19_11_25_14_questionare.csv
# Rows loaded: 11
# .\rawData/17MRW13__138_s_4_13__2016_9_19_11_32_52_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 17MRW13
# .\rawData/17MRW13__131_n_0_13__2016_9_19_10_56_5_questionare.csv
# Rows loaded: 11
# .\rawData/17MRW13__132_n_3_13__2016_9_19_11_2_34_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# **-Participant:12F
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 12F
# .\rawData/12F__188_e_0_12__2016_12_15_11_2_35_questionare.csv
# Rows loaded: 11
# .\rawData/12F__189_e_4_12__2016_12_15_11_13_16_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 12F
# .\rawData/12F__190_c_0_12__2016_12_15_11_18_53_questionare.csv
# Rows loaded: 11
# .\rawData/12F__191_c_3_12__2016_12_15_11_26_37_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 12F
# .\rawData/12F__192_s_0_12__2016_12_15_11_30_41_questionare.csv
# Rows loaded: 11
# .\rawData/12F__193_s_1_12__2016_12_15_11_37_41_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 12F
# .\rawData/12F__186_n_0_12__2016_12_15_10_41_14_questionare.csv
# Rows loaded: 11
# .\rawData/12F__187_n_2_12__2016_12_15_10_54_6_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# **-Participant:MPS15
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: MPS15
# .\rawData/MPS15__153_e_0_15__2016_9_19_14_3_15_questionare.csv
# Rows loaded: 11
# .\rawData/MPS15__154_e_4_15__2016_9_19_14_9_0_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: MPS15
# .\rawData/MPS15__147_c_0_15__2016_9_19_13_42_21_questionare.csv
# Rows loaded: 11
# .\rawData/MPS15__148_c_3_15__2016_9_19_13_47_31_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: MPS15
# .\rawData/MPS15__149_s_0_15__2016_9_19_13_49_0_questionare.csv
# Rows loaded: 11
# .\rawData/MPS15__150_s_2_15__2016_9_19_13_55_26_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: MPS15
# .\rawData/MPS15__151_n_0_15__2016_9_19_13_56_22_questionare.csv
# Rows loaded: 11
# .\rawData/MPS15__152_n_1_15__2016_9_19_14_1_48_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# **-Participant:2FQ2014
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 2FQ2014
# .\rawData/2FQ2014__32_e_0_14__2016_6_17_14_51_45_questionare.csv
# Rows loaded: 11
# .\rawData/2FQ2014__33_e_2_14__2016_6_17_15_0_13_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 2FQ2014
# .\rawData/2FQ2014__28_c_0_14__2016_6_17_14_27_57_questionare.csv
# Rows loaded: 11
# .\rawData/2FQ2014__29_c_1_14__2016_6_17_14_35_57_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 2FQ2014
# .\rawData/2FQ2014__30_s_0_14__2016_6_17_14_39_22_questionare.csv
# Rows loaded: 11
# .\rawData/2FQ2014__31_s_4_14__2016_6_17_14_47_54_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 2FQ2014
# .\rawData/2FQ2014__26_n_0_14__2016_6_17_14_15_52_questionare.csv
# Rows loaded: 11
# .\rawData/2FQ2014__27_n_3_14__2016_6_17_14_23_10_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# **-Participant:5MS17
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 5MS17
# .\rawData/5MS17__66_e_0_17__2016_7_8_13_38_41_questionare.csv
# Rows loaded: 11
# .\rawData/5MS17__67_e_2_17__2016_7_8_13_45_39_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 5MS17
# .\rawData/5MS17__64_c_0_17__2016_7_8_13_26_16_questionare.csv
# Rows loaded: 11
# .\rawData/5MS17__65_c_1_17__2016_7_8_13_34_48_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 5MS17
# .\rawData/5MS17__62_s_0_17__2016_7_8_13_14_0_questionare.csv
# Rows loaded: 11
# .\rawData/5MS17__63_s_4_17__2016_7_8_13_22_11_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 5MS17
# .\rawData/5MS17__60_n_0_17__2016_7_8_13_2_21_questionare.csv
# Rows loaded: 11
# .\rawData/5MS17__61_n_3_17__2016_7_8_13_9_6_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# **-Participant:2FS2116
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 2FS2116
# .\rawData/2FS2116__46_e_0_16__2016_6_20_16_45_16_questionare.csv
# Rows loaded: 11
# .\rawData/2FS2116__47_e_4_16__2016_6_20_16_57_14_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 2FS2116
# .\rawData/2FS2116__42_c_0_16__2016_6_20_16_16_29_questionare.csv
# Rows loaded: 11
# .\rawData/2FS2116__43_c_3_16__2016_6_20_16_25_25_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 2FS2116
# .\rawData/2FS2116__44_s_0_16__2016_6_20_16_29_41_questionare.csv
# Rows loaded: 11
# .\rawData/2FS2116__45_s_2_16__2016_6_20_16_41_43_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 2FS2116
# .\rawData/2FS2116__48_n_0_16__2016_6_20_16_59_59_questionare.csv
# Rows loaded: 11
# .\rawData/2FS2116__49_n_1_16__2016_6_20_17_10_16_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# **-Participant:18MDM19
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 18MDM19
# .\rawData/18MDM19__143_e_0_19__2016_9_19_12_40_56_questionare.csv
# Rows loaded: 11
# .\rawData/18MDM19__144_e_2_19__2016_9_19_12_50_24_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 18MDM19
# .\rawData/18MDM19__145_c_0_19__2016_9_19_12_52_54_questionare.csv
# Rows loaded: 11
# .\rawData/18MDM19__146_c_3_19__2016_9_19_13_2_52_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 18MDM19
# .\rawData/18MDM19__139_s_0_19__2016_9_19_12_16_50_questionare.csv
# Rows loaded: 11
# .\rawData/18MDM19__140_s_4_19__2016_9_19_12_26_27_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 18MDM19
# .\rawData/18MDM19__141_n_0_19__2016_9_19_12_29_4_questionare.csv
# Rows loaded: 11
# .\rawData/18MDM19__142_n_1_19__2016_9_19_12_37_31_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# **-Participant:18F
# ----Condition:e
# Loading file of type: questionare, condition: e , participant: 18F
# .\rawData/18F__182_e_0_18__2016_12_14_16_17_18_questionare.csv
# Rows loaded: 11
# .\rawData/18F__183_e_2_18__2016_12_14_16_30_51_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: van
# ----Condition:c
# Loading file of type: questionare, condition: c , participant: 18F
# .\rawData/18F__184_c_0_18__2016_12_14_16_39_58_questionare.csv
# Rows loaded: 11
# .\rawData/18F__185_c_1_18__2016_12_14_16_56_52_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: lao
# ----Condition:s
# Loading file of type: questionare, condition: s , participant: 18F
# .\rawData/18F__180_s_0_18__2016_12_14_15_52_51_questionare.csv
# Rows loaded: 11
# .\rawData/18F__181_s_4_18__2016_12_14_16_8_19_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: equ
# ----Condition:n
# Loading file of type: questionare, condition: n , participant: 18F
# .\rawData/18F__178_n_0_18__2016_12_14_15_25_43_questionare.csv
# Rows loaded: 11
# .\rawData/18F__179_n_3_18__2016_12_14_15_44_25_questionare.csv
# Rows loaded: 15
# 2 processed files.
#   Countrylet:
#   Countrylet: sur

# %%
questionnaireMeasures
# Out:
#         M1 M18 M19     M2 M20 M21 M22 M23  M24  M25   ...     M29  M2country  \
# 0    0.500   1   1  0.250   1   1   1   1   19   11   ...       4        NaN
# 1    1.000   2   1  0.250   1   3   1   1   19   11   ...       4      0.250
# 2    0.500   1   1  0.500   1   4   1   1   14   12   ...       3        NaN
# 3    0.750   4   1  0.500   4   4   1   1   14   12   ...       3      0.500
# 4    0.500   1   1  0.500   1   1   1   1    4   16   ...       1        NaN
# 5    0.875   6   1  0.500   2   3   3   1    4   16   ...       1      0.500
# 6    0.500   1   1  0.750   1   1   1   1   10    5   ...       2        NaN
# 7    0.875   5   1  0.750   1   2   2   1   10    5   ...       2      0.750
# 8    0.500   1   1  0.500   1   1   1   1   13    1   ...       4        NaN
# 9    0.625   3   3  0.500   1   3   3   1   13    1   ...       4      0.500
# 10   0.500   1   1  0.250   1   1   1   1    4    2   ...       1        NaN
# 11   0.750   3   3  0.250   1   4   3   1    4    2   ...       1      0.250
# 12   0.500   2   2  0.375   2   3   3   1    4    4   ...       3        NaN
# 13   0.375   2   2  0.375   1   3   2   1    4    4   ...       3      0.375
# 14   0.250   2   2  0.625   2   3   3   1    1    7   ...       2        NaN
# 15   0.625   4   2  0.625   2   4   4   2    1    7   ...       2      0.625
# 16   0.500   2   1  0.125   1  11   2   1   13    5   ...       1        NaN
# 17   0.625  11   1  0.125   1  11   4   1   13    5   ...       1      0.125
# 18   0.500   4   7  0.750   6  11   5   1    8   12   ...       2        NaN
# 19   0.750  10   1  0.750   3  11   8   1    8   12   ...       2      0.750
# 20   0.500   2   1  0.500   2  11   3   1    1   20   ...       3        NaN
# 21   0.375  11   1  0.500   2  11   3   1    1   20   ...       3      0.500
# 22   0.500   2   2  0.625   2  11   3   1    1   20   ...       4        NaN
# 23   0.875  11   1  0.625   2  11   5   1    1   20   ...       4      0.625
# 24   0.500   8   1  0.375  10  16  12   1    8   13   ...       2        NaN
# 25   0.500  15   2  0.375   8  15  17   8    8   13   ...       2      0.375
# 26   0.250   9   4  0.250  13  15  16   1   14    1   ...       4        NaN
# 27   0.750  16   1  0.250   9  13  15   8   14    1   ...       4      0.250
# 28   0.500   5   1  0.500   7  17   3   1    1   20   ...       3        NaN
# 29   0.500  16   2  0.500   9  14  16   3    1   20   ...       3      0.500
# ..     ...  ..  ..    ...  ..  ..  ..  ..  ...  ...   ...     ...        ...
# 160  0.500   1   3  0.625   1   1   1   1   11   11   ...       2        NaN
# 161  0.875   1   4  0.625   1   1   5   1   11   11   ...       2      0.625
# 162  0.500   1   1  0.125   1   1   1   1    1   20   ...       1        NaN
# 163  0.500   2   3  0.125   1   1   2   1    1   20   ...       1      0.125
# 164  0.500  11   6  0.250   1   1  11  11    1   20   ...       3        NaN
# 165  0.875   1   5  0.250   1   1   1   6    1   20   ...       3      0.250
# 166  0.500   7   5  0.125   5   4   8   4    9    8   ...       2        NaN
# 167  0.500   7   4  0.125   6   9  10   4    9    8   ...       2      0.125
# 168  0.500   7   4  0.500   9   6   7   3   11    8   ...       4        NaN
# 169  0.750   7   6  0.500   7   9   9   5   11    8   ...       4      0.500
# 170  0.500   5   6  0.375   4   6   8   4    6   12   ...       3        NaN
# 171  1.000   8   6  0.375   6   9   9   5    6   12   ...       3      0.375
# 172  0.500   4   3  0.500   3   4   4   3    7   13   ...       1        NaN
# 173  0.625   7   6  0.500   5   8  10   5    7   13   ...       1      0.500
# 174  0.500   1   1  0.625   1  19   1   1   17    2   ...       4        NaN
# 175  0.875   4   2  0.625   3  18   5   3   17    2   ...       4      0.625
# 176  0.500   2   2  0.375   1  19   2   1    5    5   ...       1        NaN
# 177  0.625   2   1  0.375   2  19   2   2    5    5   ...       1      0.375
# 178  0.500   3   1  0.500   1  19   2   1    1   16   ...       2        NaN
# 179  0.625   4   1  0.500   2  19   4   1    1   16   ...       2      0.500
# 180  0.500   1   1  0.500   1  19   1   1    1   19   ...       3        NaN
# 181  0.625   3   2  0.500   1  19   3   1    1   19   ...       3      0.500
# 182  0.500   6   9  0.375  17  15   8   4   11   14   ...       2        NaN
# 183  0.250  11  10  0.375  12  10   7   6   11   14   ...       2      0.375
# 184  0.500   5   7  0.250  16  14   4   3    6    8   ...       1        NaN
# 185  0.500   7   5  0.250   8  15   4   2    6    8   ...       1      0.250
# 186  0.500   9  13  0.250  11   8  10   9   15   15   ...       3        NaN
# 187  0.125  13  13  0.250  12   7   9  12   15   15   ...       3      0.250
# 188  0.000  15  16  0.500  12   7  17  11   20   18   ...       4        NaN
# 189  0.375  19  20  0.500  12   3  17  21   20   18   ...       4      0.500
#
#        M30  M30country  country  experimentNumber  orderNumber  training type  \
# 0    0.250         NaN        0               125           24     False    e
# 1    0.250       0.250        3               126           24     False    e
# 2    0.125         NaN        0               123           24     False    c
# 3    0.125       0.125        4               124           24     False    c
# 4    0.375         NaN        0               129           24     False    s
# 5    0.375       0.375        1               130           24     False    s
# 6    0.500         NaN        0               127           24     False    n
# 7    0.500       0.500        2               128           24     False    n
# 8    0.500         NaN        0               161           20     False    e
# 9    0.500       0.500        2               162           20     False    e
# 10   0.375         NaN        0               159           20     False    c
# 11   0.375       0.375        3               160           20     False    c
# 12   0.250         NaN        0               155           20     False    s
# 13   0.250       0.250        4               156           20     False    s
# 14   0.125         NaN        0               157           20     False    n
# 15   0.125       0.125        1               158           20     False    n
# 16   0.500         NaN        0                40           21     False    e
# 17   0.500       0.500        3                41           21     False    e
# 18   0.375         NaN        0                34           21     False    c
# 19   0.375       0.375        4                35           21     False    c
# 20   0.250         NaN        0                38           21     False    s
# 21   0.250       0.250        1                39           21     False    s
# 22   0.125         NaN        0                36           21     False    n
# 23   0.125       0.125        2                37           21     False    n
# 24   0.125         NaN        0               198           22     False    e
# 25   0.125       0.125        3               199           22     False    e
# 26   0.500         NaN        0               194           22     False    c
# 27   0.500       0.500        4               195           22     False    c
# 28   0.250         NaN        0               200           22     False    s
# 29   0.250       0.250        1               201           22     False    s
# ..     ...         ...      ...               ...          ...       ...  ...
# 160  0.500         NaN        0                64           17     False    c
# 161  0.500       0.500        1                65           17     False    c
# 162  0.250         NaN        0                62           17     False    s
# 163  0.250       0.250        4                63           17     False    s
# 164  0.375         NaN        0                60           17     False    n
# 165  0.375       0.375        3                61           17     False    n
# 166  0.375         NaN        0                46           16     False    e
# 167  0.375       0.375        4                47           16     False    e
# 168  0.250         NaN        0                42           16     False    c
# 169  0.250       0.250        3                43           16     False    c
# 170  0.500         NaN        0                44           16     False    s
# 171  0.500       0.500        2                45           16     False    s
# 172  0.125         NaN        0                48           16     False    n
# 173  0.125       0.125        1                49           16     False    n
# 174  0.500         NaN        0               143           19     False    e
# 175  0.500       0.500        2               144           19     False    e
# 176  0.125         NaN        0               145           19     False    c
# 177  0.125       0.125        3               146           19     False    c
# 178  0.250         NaN        0               139           19     False    s
# 179  0.250       0.250        4               140           19     False    s
# 180  0.375         NaN        0               141           19     False    n
# 181  0.375       0.375        1               142           19     False    n
# 182  0.375         NaN        0               182           18     False    e
# 183  0.375       0.375        2               183           18     False    e
# 184  0.125         NaN        0               184           18     False    c
# 185  0.125       0.125        1               185           18     False    c
# 186  0.500         NaN        0               180           18     False    s
# 187  0.500       0.500        4               181           18     False    s
# 188  0.250         NaN        0               178           18     False    n
# 189  0.250       0.250        3               179           18     False    n
#
#       userId
# 0     15FM24
# 1     15FM24
# 2     15FM24
# 3     15FM24
# 4     15FM24
# 5     15FM24
# 6     15FM24
# 7     15FM24
# 8    21MDC20
# 9    21MDC20
# 10   21MDC20
# 11   21MDC20
# 12   21MDC20
# 13   21MDC20
# 14   21MDC20
# 15   21MDC20
# 16   3MW2421
# 17   3MW2421
# 18   3MW2421
# 19   3MW2421
# 20   3MW2421
# 21   3MW2421
# 22   3MW2421
# 23   3MW2421
# 24       22F
# 25       22F
# 26       22F
# 27       22F
# 28       22F
# 29       22F
# ..       ...
# 160    5MS17
# 161    5MS17
# 162    5MS17
# 163    5MS17
# 164    5MS17
# 165    5MS17
# 166  2FS2116
# 167  2FS2116
# 168  2FS2116
# 169  2FS2116
# 170  2FS2116
# 171  2FS2116
# 172  2FS2116
# 173  2FS2116
# 174  18MDM19
# 175  18MDM19
# 176  18MDM19
# 177  18MDM19
# 178  18MDM19
# 179  18MDM19
# 180  18MDM19
# 181  18MDM19
# 182      18F
# 183      18F
# 184      18F
# 185      18F
# 186      18F
# 187      18F
# 188      18F
# 189      18F
#
# [190 rows x 21 columns]
